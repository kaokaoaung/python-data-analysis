# %% [markdown]
# #### Hotel Booking EDA

# %% [markdown]
# Data source: *https://www.kaggle.com/datasets/mojtaba142/hotel-booking*

# %% [markdown]
# #### Importing required libraries

# %%
# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Setting display option
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# #### Reading and Inspection

# %%
file_path = r'D:\personalProject\hotelBookingProject\dataset\26_07_25_hotel_booking.csv'

# %%
data = pd.read_csv(file_path)
df = pd.DataFrame(data)

# Display the first and last 5 rows to get a sense of the data
display(df.head())   # First 5 rows
display(df.tail())   # Last 5 rows
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Show the shape of the data (rows, columns)
print(f"\nDataset shape: {df.shape}")
print(f"\nDataset contains {df.shape[0]:,} rows and {df.shape[1]} columns.\n")
# Out:
# Dataset shape: (119390, 36)
#
# Dataset contains 119,390 rows and 36 columns.

# %%
# List all columns
print("\nColumn names:")
print("-"*15)
print(df.columns.to_list())
print("="*100)
# Out:
# Column names:
# ---------------
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date', 'name', 'email', 'phone-number', 'credit_card']
# ...

# %% [markdown]
# *All column names are standardized*

# %%
# Get info on data type and missing values
print("Dataframe Info:")
print("-" * 20)
print(f"\n{df.info()}")
print("="*100)
# Out:
# Dataframe Info:
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %% [markdown]
# **Data Understanding**
#
# Context:
# - This dataset contains 119390 observations for a City Hotel and a Resort Hotel. Each observation represents a hotel booking between the 1st of July 2015 and 31st of August 2017, including booking that effectively arrived and booking that were canceled.
#
# Content:
#
# - Since this is hotel real data, all data elements pertaining hotel or costumer identification were deleted.
# Four Columns, 'name', 'email', 'phone number' and 'credit_card' have been artificially created and added to the dataset.
#
# -------------------------------------------------------------
#
# Columns Defination:
#
# - **hotel:** One of the hotels is a resort hotel and the other is a city hotel.
# - **is_canceled lead_time:** Value indicating if the booking was canceled (1) or not (0).
# - **arrival_date_year:** Year of arrival date.
# - **arrival_date_month:** Month of arrival date with 12 categories: “January” to “December”.
# - **arrival_date_week_number:** Week number of the arrival date.
# - **arrival_date_day_of_month:** Day of the month of the arrival date.
# - **stays_in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# - **stays_in_week_nights:** Number of week nights (Monday to Friday) the guest stayed.
# - **adults:** Number of adults
# - **children:** Number of Children
# - **babies:** Number of Babies
# - **meal:** BB – Bed & Breakfast
# - **country:** Country of origin.
# - **market_segment:** Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - **distribution_channel:** Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - **is_repeated_guest:** Value indicating if the booking name was from a repeated guest (1) or not (0)
# - **previous_cancellations:** Number of previous bookings that were cancelled by the customer prior to the current booking
# - **previous_bookings_not_canceled:** Number of previous bookings not cancelled by the customer prior to the current booking
# - **reserved_room_type:** Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# - **assigned_room_type:** Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons
# - **booking_changes:** Number of changes/amendments made to the booking.
# - **deposit_type:** No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
# - **agent:** ID of the travel agency that made the booking
# - **company:** ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# - **days_in_waiting_list:** Number of days the booking was in the waiting list before it was confirmed to the customer
# - **customer_type:** Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when the booking is transient, but is associated to at least other transient booking
# - **adr:** Average Daily Rate (Calculated by dividing the sum of all lodging transactions by the total number of staying nights)
# - **required_car_parking_spaces:** Number of car parking spaces required by the customer
# - **total_of_special_requests:** Number of special requests made by the customer (e.g. twin bed or high floor)
# - **reservation_status:** Check-Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why
# - **reservation_status_date:** Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel
#
# ----------------------------------------------------------------

# %%
# Summary stats for numerical variable
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
# Summary stats for categorical variable
df.describe(exclude="number").T
# Out:
#                           count  unique                  top    freq
# hotel                    119390       2           City Hotel   79330
# arrival_date_month       119390      12               August   13877
# meal                     119390       5                   BB   92310
# country                  118902     177                  PRT   48590
# market_segment           119390       8            Online TA   56477
# distribution_channel     119390       5                TA/TO   97870
# reserved_room_type       119390      10                    A   85994
# assigned_room_type       119390      12                    A   74053
# deposit_type             119390       3           No Deposit  104641
# customer_type            119390       4            Transient   89613
# reservation_status       119390       3            Check-Out   75166
# reservation_status_date  119390     926           2015-10-21    1461
# name                     119390   81503      Michael Johnson      48
# ...

# %%
# Show unique values for each categorical column for better understanding
print("\nUnique values for each Categorical Column")

for col in df.select_dtypes(include= 'object').columns:
    print(f"\n=== {col.title().replace("_", " ")} === \n")
    print(f"Unique count: {df[col].nunique()}\n")
    print(f"Unique values: {df[col].unique()[0:15]}")
    print('=' * 80)
# Out:
# Unique values for each Categorical Column
#
# === Hotel ===
#
# Unique count: 2
#
# Unique values: ['Resort Hotel' 'City Hotel']
# ...
#
# === Arrival Date Month ===
#
# Unique count: 12
#
# Unique values: ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ...
#
# === Meal ===
#
# Unique count: 5
#
# Unique values: ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ...
#
# === Country ===
#
# Unique count: 177
#
# Unique values: ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE']
# ...
#
# === Market Segment ===
#
# Unique count: 8
#
# Unique values: ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# ...
#
# === Distribution Channel ===
#
# Unique count: 5
#
# Unique values: ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# ...
#
# === Reserved Room Type ===
#
# Unique count: 10
#
# Unique values: ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# ...
#
# === Assigned Room Type ===
#
# ...

# %%
print(f"There are {df.duplicated().sum():,} duplicated records in the dataset.")
# Out:
# There are 0 duplicated records in the dataset.

# %%
# Missing Columns
null_cols = df.columns[df.isna().any()]
print(f"Columns contained Null Values: \n{null_cols.to_list()}")
# Out:
# Columns contained Null Values:
# ['children', 'country', 'agent', 'company']

# %%
# Missing Values Analysis
missing_count = df.isna().sum()
missing_pct = df.isna().mean().mul(100).round(4)
missing_df = pd.DataFrame({'Missing Count': missing_count, 'Missing Percentage': missing_pct})
print("Missing Values Summary: ")
print(missing_df[missing_df['Missing Count'] > 0].sort_values(by= 'Missing Count', ascending=False))
# Out:
# Missing Values Summary:
#           Missing Count  Missing Percentage
# company          112593             94.3069
# agent             16340             13.6862
# country             488              0.4087
# children              4              0.0034

# %%
df[(df["adults"]==0) & (df["children"]==0.0) & (df["babies"]==0)][["adults", "children", "babies"]]
# Out:
#         adults  children  babies
# 2224         0       0.0       0
# 2409         0       0.0       0
# 3181         0       0.0       0
# 3684         0       0.0       0
# 3708         0       0.0       0
# ...        ...       ...     ...
# 115029       0       0.0       0
# 115091       0       0.0       0
# 116251       0       0.0       0
# 116534       0       0.0       0
# 117087       0       0.0       0
#
# [180 rows x 3 columns]

# %% [markdown]
# #### Data Cleaning

# %%
df_cleaned = df[~((df["adults"]==0) & (df["children"]==0.0) & (df["babies"]==0))]

# %%
# Drop company and agent column that have much null values
df_cleaned.drop(columns=["company", "agent"], axis=1, inplace=True)

# %%
# Drop rows having missing values
df_cleaned.dropna(axis=0, inplace=True)

# %%
# Checking is there any missing values
missing_values= df_cleaned.isna().any().any()
if missing_values:
    print("There is missing values")
else:
    print("There is no any missing values")
# Out:
# There is no any missing values

# %%
# Converting the data types
df_cleaned["arrival_date_year"]= df_cleaned["arrival_date_year"].astype(str)

# %%
df_cleaned["children"]=pd.to_numeric(df_cleaned["children"], errors="coerce")
df["children"]=df_cleaned["children"].fillna(0).astype("int64")

# %%
# Convert reservation_status_date to datetime for time-based analysis
df_cleaned['reservation_status_date'] = pd.to_datetime(df_cleaned['reservation_status_date'], errors= 'coerce')

# %% [markdown]
# #### Features Engineering

# %%
df_cleaned.insert(
    loc=3,  # position where you want to insert (e.g., 3 = fourth column)
    column='arrival_date',
    value=pd.to_datetime(
        df_cleaned['arrival_date_year'].astype(str) + '-' +
        df_cleaned['arrival_date_month'] + '-' +
        df_cleaned['arrival_date_day_of_month'].astype(str),
        format='%Y-%B-%d'
    )
)

# %%
df_cleaned.insert(
    loc=9, 
    column= "stay_duration",
    value=df_cleaned["stays_in_weekend_nights"] + 
    df_cleaned["stays_in_week_nights"]
)

# %%
df_cleaned.insert(
    loc=12,
    column= "total_visitors",
    value= df_cleaned["adults"] + 
    df_cleaned["children"] + 
    df_cleaned["babies"]
)

# %%
df_cleaned.drop(columns=["arrival_date_year", "arrival_date_month", "arrival_date_week_number", "arrival_date_day_of_month"], inplace=True)

# %%
df_cleaned.drop(columns=["name", "email", "phone-number", "credit_card", "stays_in_weekend_nights", 
                         "stays_in_week_nights", "adults", "children", "babies"], inplace=True)

# %%
df_cleaned.head()
# Out:
#           hotel  is_canceled  lead_time arrival_date  stay_duration  \
# 0  Resort Hotel            0        342   2015-07-01              0
# 1  Resort Hotel            0        737   2015-07-01              0
# 2  Resort Hotel            0          7   2015-07-01              1
# 3  Resort Hotel            0         13   2015-07-01              1
# 4  Resort Hotel            0         14   2015-07-01              2
#
#    total_visitors meal country market_segment distribution_channel  \
# 0             2.0   BB     PRT         Direct               Direct
# 1             2.0   BB     PRT         Direct               Direct
# 2             1.0   BB     GBR         Direct               Direct
# 3             1.0   BB     GBR      Corporate            Corporate
# 4             2.0   BB     GBR      Online TA                TA/TO
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# ...

# %% [markdown]
# #### **Univariate Analysis**

# %%
def identify_dtypes(df):
    """Identify and group columns by their data types."""
    cat_cols  = df.select_dtypes(include=["object", "category"]).columns
    num_cols  = df.select_dtypes(include=["int64", "float64"]).columns
    date_cols = df.select_dtypes(include=["datetime64[ns]", "datetime64"]).columns

    print(f"Categorical columns: {len(cat_cols)}\n", list(cat_cols))
    print("="*100)
    print(f"Numerical columns: {len(num_cols)}\n", list(num_cols))
    print("="*100)
    print(f"Datetime columns: {len(date_cols)}\n", list(date_cols))
    print("="*50)

identify_dtypes(df_cleaned)
# Out:
# Categorical columns: 10
#  ['hotel', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status']
# ...
# Numerical columns: 12
#  ['is_canceled', 'lead_time', 'stay_duration', 'total_visitors', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
# ...
# Datetime columns: 2
#  ['arrival_date', 'reservation_status_date']
# ...

# %%
numerical_cols=['lead_time', 'stay_duration', 'total_visitors', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 
                'total_of_special_requests',  'previous_cancellations', 
                  'previous_bookings_not_canceled', 'booking_changes']

categorical_cols=['hotel', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 
                  'deposit_type', 'customer_type', 'reservation_status', 'is_canceled', 'is_repeated_guest']

print("Number of Numerical columns: " , len(numerical_cols))
print("Number of Categorical columns: ", len(categorical_cols))
# Out:
# Number of Numerical columns:  10
# Number of Categorical columns:  12

# %%
# Summary Statistics for numerical columns
print("\nSummary Statistics for numerical Columns: \n", "-" * 45)
display(df_cleaned.describe(include= ['int', 'float']).T)
# Out:
# Summary Statistics for numerical Columns:
#  ---------------------------------------------
#                                    count        mean         std   min   25%  \
# is_canceled                     118728.0    0.371757    0.483276  0.00   0.0
# lead_time                       118728.0  104.401312  106.915284  0.00  18.0
# stay_duration                   118728.0    3.429225    2.528314  0.00   2.0
# total_visitors                  118728.0    1.973368    0.718546  1.00   2.0
# is_repeated_guest               118728.0    0.031593    0.174915  0.00   0.0
# previous_cancellations          118728.0    0.087208    0.846419  0.00   0.0
# previous_bookings_not_canceled  118728.0    0.131612    1.485300  0.00   0.0
# booking_changes                 118728.0    0.218828    0.638914  0.00   0.0
# days_in_waiting_list            118728.0    2.330638   17.633065  0.00   0.0
# adr                             118728.0  102.133442   50.389602 -6.38  70.0
# ...

# %%
# Distribution for each numerical columns (Histogram)
n_cols = len(numerical_cols)

# Determine subplot grid size (3 per row)
n_rows = (n_cols // 3) + (n_cols % 3 > 0)

# Create figure and axes
fig, axes = plt.subplots(n_rows, 3, figsize=(18, 5 * n_rows))
axes = axes.flatten()

# Plot histograms
for i, col in enumerate(numerical_cols):
    sns.histplot(df_cleaned[col], bins=10, color='skyblue', edgecolor='black', ax=axes[i])
    axes[i].set_title(f"Histogram of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")

# Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Add main title
fig.suptitle("Numerical Features Distribution (Histogram)", fontsize=16, fontweight='bold', y=1.02)

plt.tight_layout()
plt.show()

# %%
# Distribution for each numerical columns (Box plot)
sns.set(style="whitegrid")

def plot_box(df):

    num_plots = len(numerical_cols)
    num_cols_plots = 3  
    num_rows_plots = (num_plots // num_cols_plots) + (num_plots % num_cols_plots > 0)
    
    # Create subplots
    fig, axes = plt.subplots(num_rows_plots, num_cols_plots, figsize=(15, num_rows_plots * 5))
    axes = axes.flatten()

    # Plot each boxplot
    for i, col in enumerate(numerical_cols):
        sns.boxplot(x=df[col], color='skyblue', ax=axes[i])
        axes[i].set_title(f'Boxplot of {col}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel(col)
        axes[i].grid(True, linestyle='--', alpha=0.6)

    # Remove unused subplots
    for i in range(num_plots, len(axes)):
        fig.delaxes(axes[i])

    # Main title
    fig.suptitle("Numerical Features Distribution (Boxplots)",
                 fontsize=16, fontweight='bold', y=1.02)

    plt.tight_layout()
    plt.show()

# Run the function
plot_box(df_cleaned)

# %%
def summarize_datetime_columns(df):
    summaries = {}

    # Select only datetime columns
    datetime_cols = df.select_dtypes(include="datetime64").columns

    for col in datetime_cols:
        series = df[col].dropna()
        if series.empty:
            continue

        summaries[col] = {
            "min": series.min(),
            "max": series.max(),
            "span": series.max() - series.min(),
            "n_unique": series.nunique(),
            "n_missing": df[col].isna().sum(),
            "most_frequent": series.mode()[0] if not series.mode().empty else None,
            "by_year": series.dt.year.value_counts().to_dict(),
            "by_month": series.dt.month.value_counts().to_dict(),
            "by_weekday": series.dt.day_name().value_counts().to_dict(),
        }

    return pd.DataFrame(summaries).T # transpose for readability

summary = summarize_datetime_columns(df_cleaned)
display(summary)
# Out:
#                                          min                  max  \
# arrival_date             2015-07-01 00:00:00  2017-08-31 00:00:00
# reservation_status_date  2014-10-17 00:00:00  2017-09-14 00:00:00
#
#                                        span n_unique n_missing  \
# arrival_date              792 days 00:00:00      793         0
# reservation_status_date  1063 days 00:00:00      926         0
#
#                                most_frequent  \
# arrival_date             2015-12-05 00:00:00
# reservation_status_date  2015-10-21 00:00:00
#
#                                                                    by_year  \
# arrival_date                       {2016: 56357, 2017: 40541, 2015: 21830}
# reservation_status_date  {2016: 57453, 2017: 36330, 2015: 24764, 2014: ...
#
#                                                                   by_month  \
# arrival_date             {8: 13836, 7: 12611, 5: 11768, 10: 11082, 4: 1...
# ...

# %%
# Describe object(categorical) columns
print("\nSummary Statistics for Categorical Columns: \n","-" * 45)
display(df_cleaned.describe(include= 'object').T)
# Out:
# Summary Statistics for Categorical Columns:
#  ---------------------------------------------
#                        count unique         top    freq
# hotel                 118728      2  City Hotel   79143
# meal                  118728      5          BB   91789
# country               118728    177         PRT   48479
# market_segment        118728      7   Online TA   56333
# distribution_channel  118728      5       TA/TO   97612
# reserved_room_type    118728      9           A   85480
# assigned_room_type    118728     11           A   73830
# deposit_type          118728      3  No Deposit  103993
# customer_type         118728      4   Transient   89046
# reservation_status    118728      3   Check-Out   74590

# %%
# Value count for each categorical column
print("Number of Bookings & (%) for each Categorical Column\n")

for col in categorical_cols:
    print(f"{col} ({df_cleaned[col].nunique()} unique out of {df_cleaned[col].count()} values)\n")
    count= df_cleaned[col].value_counts().sort_values(ascending=False).head(15)
    count_pct= (df_cleaned[col].value_counts(normalize=True).sort_values(ascending=False).head(15)*100).round(2)
    summary_df=pd.DataFrame({"Count": count, "Count (%)": count_pct})
    print(summary_df)
    print("=" * 50)
# Out:
# Number of Bookings & (%) for each Categorical Column
#
# hotel (2 unique out of 118728 values)
#
#               Count  Count (%)
# hotel
# City Hotel    79143      66.66
# Resort Hotel  39585      33.34
# ...
# meal (5 unique out of 118728 values)
#
#            Count  Count (%)
# meal
# BB         91789      77.31
# HB         14429      12.15
# SC         10547       8.88
# Undefined   1165       0.98
# FB           798       0.67
# ...
# country (177 unique out of 118728 values)
#
#          Count  Count (%)
# country
# PRT      48479      40.83
# GBR      12120      10.21
# FRA      10401       8.76
# ESP       8560       7.21
# DEU       7285       6.14
# ITA       3761       3.17
# IRL       3374       2.84
# BEL       2342       1.97
# BRA       2222       1.87
# NLD       2103       1.77
# USA       2093       1.76
# CHE       1726       1.45
# CN        1279       1.08
# AUT       1263       1.06
# SWE       1020       0.86
# ...
# market_segment (7 unique out of 118728 values)
#
# ...

# %%
def count_plots_all(df, hue=None, rotation=0, top=None, n_cols=2, palette="Set2"):
    """
    Visualize all categorical columns in the DataFrame using count plots.

    Parameters
    ----------
    df : pd.DataFrame
        Input DataFrame.
    hue : str, optional
        Column name for grouping bars by color.
    rotation : int, optional
        Rotation angle for x-axis tick labels (default=0).
    top : int, optional
        If specified, shows only the top N categories for each column.
    n_cols : int, optional
        Number of plots per row (default=2).
    palette : str, optional
        Color palette for the plots.

    Output
    -------
    Displays multiple count plots for each categorical column.
    """

    # --- Setup figure size based on number of categorical columns ---
    n_rows = (len(categorical_cols) + n_cols - 1) // n_cols
    plt.figure(figsize=(8 * n_cols, 5 * n_rows))

    # --- Loop through categorical columns ---
    for index, col in enumerate(categorical_cols):
        plt.subplot(n_rows, n_cols, index + 1)
        order = df[col].value_counts().iloc[:top].index if top else None

        graph = sns.countplot(data=df, x=col, hue=hue, order=order, palette=palette)

        # Add count labels
        for container in graph.containers:
            graph.bar_label(container, fmt='%d', label_type='edge', fontsize=9)

        plt.title(f"Number of Bookings by {col.title().replace("_", " ")}", fontsize=12, fontweight="bold")
        plt.xlabel("")
        plt.ylabel("Count")
        plt.xticks(rotation=rotation)
        plt.grid(True, linestyle="--", alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
count_plots_all(df_cleaned, top=10, rotation=45)

# %% [markdown]
# #### Bivariate Analysis

# %%
# correlation matrix between numerical columns
num_cols=['is_canceled', 'lead_time', 'stay_duration', 'total_visitors', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 
                'total_of_special_requests',  'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']

plt.figure(figsize = (16,8))
sns.heatmap(df_cleaned[num_cols].corr(), annot = True, cmap="Blues", fmt = ".2f", linewidths = 0.2)
plt.title("Correlation between Numerical Variables", fontsize=16, fontweight="bold")
plt.show()

# %%
from scipy.stats import ttest_ind

# Split data by cancellation status
canceled = df_cleaned[df_cleaned['is_canceled'] == 1]
not_canceled = df_cleaned[df_cleaned['is_canceled'] == 0]

# Run t-test for each numeric column
results = []
for col in numerical_cols:
    # Drop missing values
    group1 = canceled[col].dropna()
    group0 = not_canceled[col].dropna()
    
    # Run independent t-test
    t_stat, p_val = ttest_ind(group1, group0, equal_var=False)
    
    results.append({
        'feature': col,
        't_statistic': t_stat,
        'p_value': p_val,
        'canceled_mean': group1.mean(),
        'not_canceled_mean': group0.mean()
    })

# Create a result table
t_test_df = pd.DataFrame(results)

# Sort by p-value (smaller p = stronger difference)
t_test_df = t_test_df.sort_values(by='p_value')

# Show results
t_test_df

t_test_df.style.format({
    't_statistic': '{:.4f}',
    'p_value': '{:.4f}',
    'canceled_mean': '{:.4f}',
    'not_canceled_mean': '{:.4f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e78c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e78c0_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_e78c0_level0_col1" class="col_heading level0 col1" >t_statistic</th>
#       <th id="T_e78c0_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_e78c0_level0_col3" class="col_heading level0 col3" >canceled_mean</th>
#       <th id="T_e78c0_level0_col4" class="col_heading level0 col4" >not_canceled_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e78c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e78c0_row0_col0" class="data row0 col0" >lead_time</td>
#       <td id="T_e78c0_row0_col1" class="data row0 col1" >98.3341</td>
#       <td id="T_e78c0_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_e78c0_row0_col3" class="data row0 col3" >144.9300</td>
# ...

# %%
def box_plots_vs_target(df, target_col, numerical_cols, n_cols=2, palette="Set2"):
    """
    Visualize relationships between a binary/categorical target 
    and selected numeric predictors using box plots.

    Parameters
    ----------
    df : pd.DataFrame
        Input DataFrame.
    target_col : str
        The categorical/binary target column (e.g., 'is_canceled').
    numerical_cols : list
        List of numeric column names to plot.
    n_cols : int
        Number of plots per row.
    palette : str
        Color palette for box plots.
    """

    # --- Validation ---
    if target_col not in df.columns:
        raise ValueError(f"'{target_col}' not found in DataFrame columns.")
    if not numerical_cols:
        print("No numerical columns provided.")
        return

    # Ensure target is treated as categorical
    df = df.copy()
    df[target_col] = df[target_col].astype("category")

    # Exclude target if it accidentally appears in numerical list
    num_cols = [col for col in numerical_cols if col != target_col]

    # --- Plot setup ---
    n_rows = (len(num_cols) + n_cols - 1) // n_cols
    plt.figure(figsize=(8 * n_cols, 5 * n_rows))

    for index, col in enumerate(num_cols):
        plt.subplot(n_rows, n_cols, index + 1)

        sns.boxplot(data=df, x=target_col, y=col, palette=palette)
        plt.title(f"Cancellation by {col.title().replace('_', ' ')}",
                  fontsize=12, fontweight="bold")
        plt.xlabel(target_col)
        plt.ylabel(col)
        plt.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    plt.show()

# %%
box_plots_vs_target(df_cleaned, target_col="is_canceled", numerical_cols=numerical_cols, n_cols=3)

# %%
from scipy.stats import chi2_contingency

# Set alpha significance level
alpha = 0.05

for col in categorical_cols:
    print(f"\n=== {col.title().replace('_', ' ')} ===")

    # --- Crosstab (percentage per category) ---
    crosstab = pd.crosstab(df_cleaned[col], df_cleaned["is_canceled"], normalize="index") * 100
    crosstab = crosstab.rename(columns={0: "Not Canceled (%)", 1: "Canceled (%)"})
    print(crosstab.sort_values("Canceled (%)", ascending=False).round(2))

    # --- Chi-square test ---
    contingency = pd.crosstab(df_cleaned[col], df_cleaned["is_canceled"])
    chi2, p, dof, expected = chi2_contingency(contingency)
    significance = "✅ Significant" if p < alpha else "❌ Not Significant"

    print(f"{col:<30} | p-value: {p:.4f} | {significance}")
    print("=" * 70)

print(f"\nSignificance Level (alpha): {alpha}")
# Out:
# === Hotel ===
# is_canceled   Not Canceled (%)  Canceled (%)
# hotel
# City Hotel               58.23         41.77
# Resort Hotel             72.02         27.98
# hotel                          | p-value: 0.0000 | ✅ Significant
# ...
#
# === Meal ===
# is_canceled  Not Canceled (%)  Canceled (%)
# meal
# FB                      40.10         59.90
# BB                      62.47         37.53
# SC                      62.59         37.41
# HB                      65.49         34.51
# Undefined               75.45         24.55
# meal                           | p-value: 0.0000 | ✅ Significant
# ...
#
# === Country ===
# is_canceled  Not Canceled (%)  Canceled (%)
# country
# KHM                       0.0         100.0
# BEN                       0.0         100.0
# GGY                       0.0         100.0
# GLP                       0.0         100.0
# HND                       0.0         100.0
# ...                       ...           ...
# MMR                     100.0           0.0
# ...

# %%
from scipy.stats import chi2_contingency

def cat_plots_vs_target(df, target_col, categorical_cols, top=None, n_cols=2, palette="Set2", alpha=0.05):
    """
    Visualize relationships between a binary/categorical target 
    and all categorical predictors using count plots + Chi-square test.
    """

    # --- Validation ---
    if target_col not in df.columns:
        raise ValueError(f"'{target_col}' not found in DataFrame columns.")
    if not categorical_cols:
        print("No categorical columns provided.")
        return

    df = df.copy()
    df[target_col] = df[target_col].astype("category")

    # Exclude target column if present
    cat_cols = [col for col in categorical_cols if col != target_col]

    # --- Plot setup ---
    n_rows = (len(cat_cols) + n_cols - 1) // n_cols
    plt.figure(figsize=(8 * n_cols, 5 * n_rows))

 
    for index, col in enumerate(cat_cols):
        plt.subplot(n_rows, n_cols, index + 1)

        # Select top N categories if specified
        order = df[col].value_counts().iloc[:top].index if top else df[col].value_counts().index

        # --- Count plot ---
        ax = sns.countplot(data=df, x=col, hue=target_col, order=order, palette=palette)

        # --- Add percentage annotations safely ---
        total_per_category = df[col].value_counts(normalize=False)
        for container in ax.containers:
            labels = [f'{(v.get_height() / total_per_category.get(label.get_text(), 1)):.1%}'
                      if total_per_category.get(label.get_text(), 0) > 0 else ''
                      for v, label in zip(container, ax.get_xticklabels())]
            ax.bar_label(container, labels=labels, label_type='edge', fontsize=8, padding=2)

        # --- Plot formatting ---
        plt.title(f"Cancellation by {col.title().replace('_', ' ')}",
                  fontsize=12, fontweight="bold")
        plt.xlabel(col)
        plt.ylabel("Count")
        plt.xticks(rotation=30)
        plt.legend(title=target_col, loc="upper right")
        plt.grid(True, linestyle="--", alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
cat_plots_vs_target(
    df_cleaned,
    target_col="is_canceled",
    categorical_cols=categorical_cols,
    n_cols=3,
    top=5
)
